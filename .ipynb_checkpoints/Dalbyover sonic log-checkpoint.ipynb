# %% [markdown]
# # Sonic log - Dalbyover 59.459
#
# Reading LAS wireline log file, calculate sonic velocity from arrival times.
#
# Problems so far:
#
# 1. Wrong scaling of the entire log. The velocities are about (?) 3 times too high. I also tried to calculate velocities from the distances according to the [factsheet](https://github.com/TobbeTripitaka/Dalbyover/blob/master/Sonic-slimhole_TRGS8068.pdf) of the tool (0.60, 0.80 and 1.00m) and the times in $\mu$s (column 2,3,4 in LAS-file), but the results are exacetly the same as the precalculated velocities (column 5,6,7 in LAS-file). The header of the [LAS files](https://github.com/TobbeTripitaka/Dalbyover/tree/master/data) states that the measurements are in _m_ and _km_ but this might be wrong.
#
#
# 2. R2R1 and R3R2 don't agree in the upper 40m, the most interesting depths fo us. Can it be related to Cycle Skipping? Can it be a time mute? Or are we simply measuring the mud and water velocities as the velocities in dry chalk are lower.
#
# To be continued.

# %%
#Plot in document
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import numpy.lib.recfunctions
import matplotlib.pyplot as plt
import scipy.signal as signal
    
def read_LAS(file_name,file_header):
    '''
    Read LAS file from Robertson Geologging WinLogger
    Specify file name, header and delimiter. Also converts depth to an integer for
    joining datasets. 
    '''
    in_file_A = pd.read_csv(file_name, header=file_header,delim_whitespace=True, 
                          na_values=['1.#J',0,-999.25])
    
    # LAS files have an extra carachter that adds an extra column
    in_file = in_file_A[in_file_A.columns[:-1]]
    in_file.columns = in_file_A.columns[1:]
    
    #print in_file.dtypes
    #print in_file.head()
    #print in_file.tail()
    #print in_file.describe()
    return in_file

def smooth_filter(raw,kernel=11):
    '''
    Apply median filter, set window size. Must be odd number. 

    '''
    return signal.medfilt(raw, kernel_size=kernel)

def well_plot():
    '''
    Using matplotlib to plot a well log. 
    '''
    return

# In files 
in_sonic = ['data/TRGS8068-Dalbyover5.LAS', 'data/TRGS8068-Dalbyover4.LAS']
in_electric = ['data/TCDS3719-Dalbyover1.LAS', 'data/TCDS3719-Dalbyover2.LAS']

# Read and merge sonic logs
sonic = pd.concat([read_LAS(in_sonic[1],38), read_LAS(in_sonic[0],38)])
sonic.rename(columns={'OUT6': 'NGAM_S'}, inplace=True)

# Read and join electric logs
electric = pd.merge(read_LAS(in_electric[0],33), read_LAS(in_electric[1],33), 
                    on='DEPTH', how='outer',suffixes=('_E1', '_E2'))

# Merge all data on depth
data = pd.merge(sonic, electric, on='DEPTH', how='outer')
data.sort_values('DEPTH', ascending=True)

#print data.describe()

# Save a file with sonic and electric data
data.to_csv('log_data.txt')
# Out:
#               DEPTH          TIME         TXRX1         TXRX2         TXRX3  \
# count  36101.000000  35793.000000  35545.000000  35525.000000  35505.000000
# mean     171.781107   8613.356094     76.465066    100.549155    132.618141
# std       99.353620   5212.351281     22.480223     28.831981     57.565214
# min       -0.190000     36.780000   -847.500000   -844.640000   -842.070000
# 25%       90.070000   4309.620000     67.430000     88.140000    108.570000
# 50%      167.520000   8406.840000     72.000000     94.710000    117.000000
# 75%      257.770000  12725.040000     76.140000    100.430000    124.000000
# max      348.020000  18800.750000    141.140000    210.570000    408.430000
#
#                R1R2          R2R3          R1R3        NGAM_S       NGAM_E1  \
# count  35096.000000  35084.000000  35105.000000  35257.000000  35882.000000
# mean       8.684021      8.380601      8.474931     22.983172      8.616999
# std        9.626540     11.620274     14.182596    129.494705     12.681535
# min     -350.000000  -1400.000000  -1400.000000   -939.910000   -937.200000
# 25%        8.190000      8.330000      8.280000      7.400000      6.100000
# 50%        8.860000      9.090000      8.920000      9.030000      7.870000
# 75%        9.790000      9.860000      9.760000     11.460000     10.250000
# max     1400.000000    700.000000    560.000000   1718.280000     67.800000
#
#             COND_E1       TEMP_E1       TEMP_E2      COND_E2       NGAM_E2
# count  35847.000000  35851.000000  35895.000000  35891.00000  35921.000000
# mean     357.693677     10.304765     10.906891  17057.74888     11.081884
# std      130.163226      9.676645      9.727463  15607.17204     13.016892
# min     -907.420000   -908.480000   -909.330000   -907.42000   -940.470000
# 25%      380.460000      8.770000      9.290000    403.71000      8.040000
# 50%      399.450000     10.230000     10.990000  14177.04000     10.160000
# 75%      418.190000     11.970000     12.570000  34817.71000     12.990000
# max     1604.930000     13.380000     14.600000  38766.06000     84.850000
#        DEPTH  TIME  TXRX1  TXRX2  TXRX3  R1R2  R2R3  R1R3  NGAM_S  NGAM_E1  \
# 36097   2.85   NaN    NaN    NaN    NaN   NaN   NaN   NaN     NaN    24.22
# 36098   2.86   NaN    NaN    NaN    NaN   NaN   NaN   NaN     NaN    23.95
# 36099   2.87   NaN    NaN    NaN    NaN   NaN   NaN   NaN     NaN    24.22
# 36100   2.88   NaN    NaN    NaN    NaN   NaN   NaN   NaN     NaN    25.28
# 36101   2.89   NaN    NaN    NaN    NaN   NaN   NaN   NaN     NaN    23.95
#
#        COND_E1  TEMP_E1  TEMP_E2  COND_E2  NGAM_E2
# 36097    10.86     8.58    14.57    10.86    37.48
# 36098    10.86     8.58    14.57    10.86    34.56
# 36099    10.86     8.57    14.57    10.86    35.53
# 36100    10.86     8.57    14.57    10.86    36.06
# 36101    10.86     8.57    14.56    10.86    35.53

# %% [markdown]
# Plots of velocities from R2-R1 and R3-R2. R3-R1 is commented out for clarity.
#
# To fix:
# Make NaN at -999.25 and Sonic missing
# Make calculated velocities and show with tools velocities
# Calculate a fex exemples
# Inspect data
# Plot gamma logs and differences/variations
# Make functions and loops
# Print dtype for data array
# water mud curve

# %%
# Try scaling of velocity. Try e.g. 0.3048, meters to feet.
C = 0.3048

# m us to s 0.3048
u = 10**-6 

# Calculate velocity from spacing (20cm) and arrival time difference
#np.seterr(divide='ignore')
v1 = 0.2/(data['TXRX2']-data['TXRX1'])/u
v2 = 0.2/(data['TXRX3']-data['TXRX2'])/u

print v1.describe()
print v2.describe()

print v1.dtypes
print v1.head()
print v1.tail()


#print max(v1)
#print max(data['TXRX2'])

#print v1.shape
#print data['DEPTH'].shape
#v3 = C*0.40/(in_data[:,4]-in_data[:,2])		#R3-R1


# Calculate a few exemples

sample_depths = [30,10.2,20,100,30]
sample_depths.sort()

#for sample in sample_depths:
#    depth_index = np.where(in_data[:,0]==sample)
#    v1 = 1000*C*0.20/(sonic[depth_index,3]-sonic[depth_index,2]) #R2-R1
#    v2 = 1000*C*0.20/(sonic[depth_index,4]-sonic[depth_index,3]) #R3-R2
#    print 'v at %.2fm is %f (R2-R1) and %f (R3-R2).' % (sample,v1,v2)
# Out:
# count    3.552500e+04
# mean              inf
# std               NaN
# min     -3.508772e+05
# 25%      8.186656e+03
# 50%      8.916630e+03
# 75%      9.789525e+03
# max               inf
# dtype: float64
# count    3.550500e+04
# mean              inf
# std               NaN
# min     -1.428571e+06
# 25%      8.333333e+03
# 50%      9.090909e+03
# 75%      9.861933e+03
# max               inf
# dtype: float64
# float64
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# dtype: float64
# 36097   NaN
# 36098   NaN
# 36099   NaN
# 36100   NaN
# 36101   NaN
# dtype: float64

# %%
# Plot sonic

# Apply smoothing filter kernel is median window size, must be odd
kernel=99

fig = plt.figure(figsize=(10,12))
fig.subplots_adjust(wspace=0.05)

ax1 = plt.subplot(121)
ax1.set_ylim(ax1.get_ylim()[::-1]) 
plt.title('Sonic velocity (km/s)', fontsize = 12)
plt.ylabel('Well depth (m)', fontsize = 12)

#Plot mud velocity 5,300 feet/s
plt.axvline(x=C*5.188, color='red', label='mud',lw=2,alpha=0.5,ymin=0.85)
plt.axvline(x=1.489, color='blue', label='water',lw=2,alpha=0.5,ymin=0.85)

#Plot raw data
plt.plot(C*data['R1R2'],data['DEPTH']+0.1, lw=0.5, color='black', alpha=0.3)
plt.plot(C*data['R2R3'],data['DEPTH']-0.1, lw=0.5, color='green', alpha=0.3)
#R1R3

#Plot filtered data
plt.plot(smooth_filter(C*data['R1R2'],kernel),data['DEPTH']+0.1, lw=1.2, color='black', alpha=0.9)
plt.plot(smooth_filter(C*data['R2R3'],kernel),data['DEPTH']-0.1, lw=1.2, color='green', alpha=0.9)


#plt.plot(v1,data['DEPTH']/100-0.1, lw=0.5, color='red', alpha=0.9)
#plt.plot(v2,data['DEPTH']/100-0.1, lw=0.5, color='black', alpha=0.9)



#smooth R1R3

plt.setp(ax1.get_xticklabels(), fontsize=12)
plt.xlim(0, 15*C)
plt.grid()
plt.legend()

# Plot gamma
ax2 = plt.subplot(122, sharey=ax1)
plt.title('Gamma', fontsize = 12)
plt.plot(data['NGAM_E1'],data['DEPTH'], lw=0.5, color='black', label='API', alpha=0.8)
plt.xlim(0, 30)
plt.ylim(max(data['DEPTH']),0)
plt.setp(ax2.get_yticklabels(), visible=False)
plt.grid()
plt.legend()

plt.show()

# %% [markdown]
# Sonic velocities in drill mud is in the range of 185-189 $\mu/ ft$. See [Petrowiki](http://petrowiki.org/Porosity_evaluation_with_acoustic_logging). The lower value is typical for salt mud and showed as a red line in sonic plot. Also velocity for water at about 10 degrees is plotted in blue.
# The velocities for the upper section are very close to these values. As very low velocities are expected in the chalk, the measured signal might actually be from the mud.
#
# ## Conductivity
# TCDS3719-Dalbyover1.LAS and TCDS3719-Dalbyover2.LAS contains conductivity, temperature and gamma logs.

# %%
#Make array where column 1 is counting from min(array 1 and 2) to max(array 1 and 2) in 
#smallest steps
#Loop steps and look in both logs if they are
#Flag/count differences
#Calculate difference where non is zero






for depth in electric[0:10,0]:
    print depth
#    depth_index = np.where(electric_extra[:,0]==depth)
# Out:
# -0.19
# -0.18
# -0.17
# -0.16
# -0.15
# -0.14
# -0.13
# -0.12
# -0.11
# -0.1

# %%
dtype = [('DEPTH', np.float), 
        ('TIME_SONIC', np.float),
        ('TXRX1', np.float),
        ('TXRX2', np.float),
        ('TXRX3', np.float),
        ('R1R2', np.float),
        ('R2R3', np.float),
        ('R1R3', np.float),
        ('NGAM_SONIC', np.float),
        ('TEMP_ELEC1', np.float),
        ('COND_ELEC1', np.float),
        ('NGAM_ELEC1', np.float),
        ('TEMP_ELEC2', np.float),
        ('COND_ELEC2', np.float),
        ('NGAM_ELEC2', np.float)]
